# %%
import importlib.util
import subprocess
import sys

def install_and_import(module_name):
    if importlib.util.find_spec(module_name) is None:
        print(f"{module_name} not found. Installing...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", module_name])
    else:
        print(f"{module_name} is already installed.")

# Use the function for the libraries
install_and_import('pandas')
install_and_import('numpy')
install_and_import('matplotlib')
# Out:
# pandas is already installed.
# numpy is already installed.
# matplotlib is already installed.

# %% [markdown]
# # 1. Extract HOSE actual price and gbm paths

# %%
import pandas as pd
import numpy as np
import glob
import os

# Load actual prices for HOSE
hose_df_2023 = pd.read_csv('./data/hose_df_2023.csv')
hose_df_2023['date'] = pd.to_datetime(hose_df_2023['date'])

# Get the list of HOSE tickers
hose_tickers = hose_df_2023['ticker'].unique()

# Get the list of all simulated path files
path_files = glob.glob('./gbm_price/*.csv')

# Filter the path files to include only HOSE tickers
hose_path_files = [file for file in path_files if os.path.basename(file).replace('.csv', '') in hose_tickers]

# Initialize an empty DataFrame to store the average paths
hose_average_gbm = pd.DataFrame()
hose_average_gbm['date'] = sorted(hose_df_2023['date'].unique())
hose_average_gbm['date'] = pd.to_datetime(hose_average_gbm['date'])

# Load each file, calculate the average path, and add to the DataFrame
for file in hose_path_files:
    ticker = os.path.basename(file).replace('.csv', '')
    sim_df = pd.read_csv(file)
    sim_df['date'] = pd.to_datetime(sim_df['date'])
    
    # Calculate the average path
    sim_df['average_path'] = sim_df.iloc[:, 1:].mean(axis=1)
    
    # Merge the average path into the main DataFrame
    hose_average_gbm = hose_average_gbm.merge(sim_df[['date', 'average_path']], on='date', how='left')
    hose_average_gbm = hose_average_gbm.rename(columns={'average_path': ticker})

# Ensure the columns are in the correct order
cols = ['date'] + [os.path.basename(file).replace('.csv', '') for file in hose_path_files]
hose_average_gbm = hose_average_gbm[cols]

# Save the result to a CSV file
hose_average_gbm.to_csv('average_paths_hose.csv', index=False)

# Display the first few rows of the DataFrame to verify
hose_average_gbm.head()
# Out:
#         date        ACB        BCM        BID        BVH        CTG  \
# 0 2023-01-03  21.953213  80.025451  39.301068  46.634277  27.327769
# 1 2023-01-04  21.904796  80.098034  39.290642  46.571368  27.305737
# 2 2023-01-05  21.857003  80.190791  39.302727  46.532818  27.286698
# 3 2023-01-06  21.822504  80.237711  39.321967  46.506483  27.269593
# 4 2023-01-09  21.767886  80.316616  39.341731  46.449118  27.250260
#
#          FPT         GAS        GVR        HDB  ...        VCB        VHM  \
# 0  76.892024  101.989223  13.740464  16.053928  ...  80.201098  47.886835
# 1  76.876245  102.020581  13.679972  16.007530  ...  80.217336  47.733062
# 2  76.779536  102.022701  13.619250  15.965420  ...  80.229581  47.607799
# 3  76.721922  102.010618  13.567718  15.914317  ...  80.224476  47.492454
# 4  76.635813  102.053766  13.517154  15.871490  ...  80.233128  47.375691
#
#          VIB        VIC         VJC    VN30INDEX      VNINDEX        VNM  \
# 0  18.901593  53.674086  109.418791  1008.701753  1009.656838  76.431358
# 1  18.830319  53.535336  109.354238  1007.088965  1007.763634  76.402449
# 2  18.766577  53.402458  109.288090  1005.391368  1006.095537  76.376190
# 3  18.710708  53.270702  109.221507  1003.556605  1004.711712  76.317900
# 4  18.656564  53.129960  109.183221  1001.541615  1003.108914  76.286104
#
#          VPB        VRE
# 0  17.968025  26.992686
# 1  17.917365  26.985897
# 2  17.874119  26.973237
# 3  17.826057  26.960437
# 4  17.771338  26.931107
#
# [5 rows x 33 columns]

# %% [markdown]
# # 2. Calculate MAPE for HOSE stocks

# %%
import pandas as pd
import numpy as np

# Function to calculate MAPE
def calculate_mape(actual, predicted):
    return np.mean(np.abs((actual - predicted) / actual)) * 100

# Load actual prices for HOSE
hose_df_2023 = pd.read_csv('./data/hose_df_2023.csv')
hose_df_2023['date'] = pd.to_datetime(hose_df_2023['date'])

# Sort the actual prices by date
hose_df_2023 = hose_df_2023.sort_values(by='date')

# Load the average GBM paths
average_paths_df = pd.read_csv('average_paths_hose.csv')
average_paths_df['date'] = pd.to_datetime(average_paths_df['date'])

# Initialize the hose_mape DataFrame
columns = ['1_week', '2_week', '3_week', '1_month', '2_month', '6_month', '12_month']
hose_mape = pd.DataFrame(index=hose_df_2023['ticker'].unique(), columns=columns)

# Time marks in business days (approximation)
time_marks = {
    '1_week': 5,
    '2_week': 10,
    '3_week': 15,
    '1_month': 21,
    '2_month': 42,
    '6_month': 120,
    '12_month': 248
}

# Calculate MAPE for each ticker
for ticker in hose_df_2023['ticker'].unique():
    actual_prices = hose_df_2023[hose_df_2023['ticker'] == ticker].set_index('date')['close']
    predicted_prices = average_paths_df.set_index('date')[ticker]

    for period, days in time_marks.items():
        if len(actual_prices) > days:
            actual_price = actual_prices.iloc[days]
            predicted_price = predicted_prices.iloc[days]

            mape = calculate_mape(actual_price, predicted_price)
            hose_mape.at[ticker, period] = mape
# Sort the hose_mape DataFrame by ticker
hose_mape_sorted = hose_mape.sort_index()

# Save the hose_mape DataFrame to a CSV file
hose_mape.to_csv('hose_mape.csv')

# Display the first few rows of the hose_mape DataFrame to verify
print(hose_mape.head())
# Out:
#         1_week     2_week     3_week    1_month    2_month    6_month  \
# PLX  14.612816  16.650529  16.425363  18.321186  25.656034  34.605144
# BID   4.743284  12.505548  12.744901  11.259949  16.927973   8.012674
# BVH   3.311404   4.949126   8.771065   7.010418    8.54407   3.054115
# CTG   4.631757  11.390235  11.480851  10.388973  10.679559  17.232775
# FPT   4.802112   6.953766   9.008997   6.911511   7.687709  18.655248
#
#       12_month
# PLX  46.360213
# BID   7.315655
# BVH   1.235722
# CTG  20.516486
# FPT  34.070984

# %%
import pandas as pd

# Load data
hose_mape = pd.read_csv('./mape/hose_mape.csv')
hose_df_2023 = pd.read_csv('./data/hose_df_2023.csv')
hose_average = pd.read_csv('./average_paths_hose.csv')

# Convert date columns to datetime
hose_df_2023['date'] = pd.to_datetime(hose_df_2023['date'])
hose_average['date'] = pd.to_datetime(hose_average['date'])

# Sort hose_df_2023 and hose_average by date and ticker
hose_df_2023 = hose_df_2023.sort_values(by=['ticker', 'date'])
hose_average = hose_average.sort_values(by='date')

# Sample tickers (replace this with your actual unique tickers)
unique_tickers = hose_df_2023['ticker'].unique()

# Create an empty DataFrame 'hose_short_term' with tickers as index
hose_short_term = pd.DataFrame(index=unique_tickers)

# Helper function to safely retrieve values
def get_close_price_at_index(df, ticker, index):
    close_prices = df[df['ticker'] == ticker]['close'].values
    if len(close_prices) > index:
        return close_prices[index]
    else:
        return np.nan

# Extract actual, predicted prices and MAPE for each period
periods = {
    '1_week': 5,
    '2_week': 10,
    '3_week': 15,
    '1_month': 21,
}

for period, index in periods.items():
    actual_prices = [get_close_price_at_index(hose_df_2023, ticker, index) for ticker in unique_tickers]
    hose_short_term[f'{period}_actual'] = actual_prices
    
    predicted_prices = hose_average.iloc[index, 1:33].values
    hose_short_term[f'{period}_predict'] = predicted_prices
    
    hose_short_term[f'{period}_mape'] = hose_mape[period].values

# Save as a CSV file to the 'mape' folder
hose_short_term.to_csv('./mape/hose_short_term.csv')

# Display the first few rows of the DataFrame
hose_short_term.head()
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.
#      1_week_actual 1_week_predict  1_week_mape  2_week_actual 2_week_predict  \
# ACB          23.45      21.720722     7.374319          25.30      21.503398
# BCM          82.00      80.432686     1.911359          83.50      80.800994
# BID          41.30      39.341024     4.743284          44.95      39.328756
# BVH          48.00      46.410526     3.311404          48.60      46.194725
# CTG          28.55      27.227633     4.631757          30.60      27.114588
#
#      2_week_mape  3_week_actual 3_week_predict  3_week_mape  1_month_actual  \
# ACB    15.006332          26.05      21.296609    18.247182           24.65
# BCM     3.232342          84.80      81.145337     4.309744           84.50
# BID    12.505548          45.10      39.352049    12.744901           44.50
# BVH     4.949126          50.40      45.979383     8.771065           49.25
# CTG    11.390235          30.50      26.998341    11.480851           29.90
#
#     1_month_predict  1_month_mape
# ACB       21.020345     14.724767
# BCM       81.580476      3.455058
# BID       39.489323     11.259949
# BVH       45.797369      7.010418
# CTG       26.793697     10.388973

# %%
import pandas as pd

# Load data
hose_mape = pd.read_csv('./mape/hose_mape.csv')
hose_df_2023 = pd.read_csv('./data/hose_df_2023.csv')
hose_average = pd.read_csv('./average_paths_hose.csv')

# Convert date columns to datetime
hose_df_2023['date'] = pd.to_datetime(hose_df_2023['date'])
hose_average['date'] = pd.to_datetime(hose_average['date'])

# Sort hose_df_2023 and hose_average by date and ticker
hose_df_2023 = hose_df_2023.sort_values(by=['ticker', 'date'])
hose_average = hose_average.sort_values(by='date')

# Sample tickers (replace this with your actual unique tickers)
unique_tickers = hose_df_2023['ticker'].unique()

# Create an empty DataFrame 'hose_long_term' with tickers as index
hose_long_term = pd.DataFrame(index=unique_tickers)

# Extract actual, predicted prices and MAPE for each period
periods = {
    '2_month': 42,
    '6_month': 120,
    '12_month': 248
}

for period, index in periods.items():
    actual_prices = [get_close_price_at_index(hose_df_2023, ticker, index) for ticker in unique_tickers]
    hose_long_term[f'{period}_actual'] = actual_prices
    
    predicted_prices = hose_average.iloc[index, 1:33].values
    hose_long_term[f'{period}_predict'] = predicted_prices
    
    hose_long_term[f'{period}_mape'] = hose_mape[period].values

# Save as a CSV file to the 'mape' folder
hose_long_term.to_csv('./mape/hose_long_term.csv')
hose_long_term.to_excel('./mape/hose_long_term.xlsx')

# Display the first few rows of the DataFrame
hose_long_term.head()
# Out:
#      2_month_actual 2_month_predict  2_month_mape  6_month_actual  \
# ACB           25.35        20.25057     20.116096           22.05
# BCM           84.00       83.140764      1.022900           79.20
# BID           47.65       39.583821     16.927973           43.35
# BVH           49.45       45.224957      8.544070           44.10
# CTG           29.40        26.26021     10.679559           29.50
#
#     6_month_predict  6_month_mape  12_month_actual 12_month_predict  \
# ACB       17.488835     20.685555             23.9        13.722723
# BCM       89.008926     12.385007             62.9       100.168574
# BID       39.876506      8.012674             43.4        40.225006
# BVH       42.753135      3.054115             39.5         39.01189
# CTG       24.416331     17.232775             27.1        21.540032
#
#      12_month_mape
# ACB      42.582750
# BCM      59.250516
# BID       7.315655
# BVH       1.235722
# CTG      20.516486

# %% [markdown]
# # 3. Extract DSE actual_price and DSE gbm paths

# %%
import pandas as pd
import numpy as np
import glob
import os

# Load actual prices for DSE
dse_df_2023 = pd.read_csv('./data/dse_df_2023.csv')
dse_df_2023['date'] = pd.to_datetime(dse_df_2023['date'])

# Get the list of DSE tickers
dse_tickers = dse_df_2023['ticker'].unique()

# Get the list of all simulated path files
path_files = glob.glob('./gbm_price/*.csv')

# Filter the path files to include only DSE tickers
dse_path_files = [file for file in path_files if os.path.basename(file).replace('.csv', '') in dse_tickers]

# Initialize an empty DataFrame to store the average paths
dse_average_gbm = pd.DataFrame()
dse_average_gbm['date'] = sorted(dse_df_2023['date'].unique())
dse_average_gbm['date'] = pd.to_datetime(dse_average_gbm['date'])

# Load each file, calculate the average path, and add to the DataFrame
for file in dse_path_files:
    ticker = os.path.basename(file).replace('.csv', '')
    sim_df = pd.read_csv(file)
    sim_df['date'] = pd.to_datetime(sim_df['date'])
    
    # Calculate the average path
    sim_df['average_path'] = sim_df.iloc[:, 1:].mean(axis=1)
    
    # Merge the average path into the main DataFrame
    dse_average_gbm = dse_average_gbm.merge(sim_df[['date', 'average_path']], on='date', how='left')
    dse_average_gbm = dse_average_gbm.rename(columns={'average_path': ticker})

# Ensure the columns are in the correct order
cols = ['date'] + [os.path.basename(file).replace('.csv', '') for file in dse_path_files]
dse_average_gbm = dse_average_gbm[cols]

# Save the result to a CSV file
dse_average_gbm.to_csv('average_paths_dse.csv', index=False)

# Display the first few rows of the DataFrame to verify
dse_average_gbm.head()
# Out:
#         date       00DS30       00DSEX       BATBC  BBSCABLES  BEACONPHAR  \
# 0 2023-01-01  2193.819464  6204.637070  518.306043  49.866365  304.775145
# 1 2023-01-02  2192.591833  6202.447570  517.888230  49.853301  304.971680
# 2 2023-01-03  2191.515471  6198.181774  517.370572  49.816966  305.021867
# 3 2023-01-04  2190.202905  6196.356243  516.980176  49.785450  305.306788
# 4 2023-01-05  2188.967792  6193.251144  516.566055  49.757176  305.664077
#
#       BEXIMCO   BRACBANK         BSC       BSCCL  ...  ORIONPHARM  POWERGRID  \
# 0  115.441056  38.444144  116.243415  218.951186  ...   82.808104  52.359071
# 1  115.317636  38.388564  116.558866  219.039573  ...   82.725880        NaN
# 2  115.174560  38.320222  116.888605  219.138930  ...   82.678170  52.313781
# 3  115.030059  38.253408  117.114397  219.156209  ...   82.623450  52.288058
# 4  114.895551  38.190672  117.371366  219.191483  ...   82.532473  52.256933
#
#         RENATA       ROBI    SEAPEARL  SOUTHEASTB  SQURPHARMA   TITASGAS  \
# 0  1217.639744  29.979342  192.048357   13.793122  209.764833  40.939024
# 1  1217.216318  29.972946  193.262261   13.786600  209.726659  40.955688
# 2  1216.769623  29.963443  194.385148   13.780588  209.701867  40.971910
# 3  1216.516704  29.944015  195.754521   13.773501  209.701720  40.996652
# 4  1216.259146  29.935415  196.826532   13.763269  209.680595        NaN
#
#    UNIQUEHRL      UPGDCL
# 0  56.026624  233.644405
# 1  56.108491  233.570472
# 2  56.124813  233.483812
# 3  56.193760  233.388495
# 4  56.168586         NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# # 4. Calculate MAPE for DSE stock

# %%
import pandas as pd
import numpy as np

# Function to calculate MAPE
def calculate_mape(actual, predicted):
    return np.mean(np.abs((actual - predicted) / actual)) * 100

# Load actual prices for DSE
dse_df_2023 = pd.read_csv('./data/dse_df_2023.csv')
dse_df_2023['date'] = pd.to_datetime(dse_df_2023['date'])

# Sort the actual prices by date
dse_df_2023 = dse_df_2023.sort_values(by='date')

# Load the average GBM paths
average_paths_df = pd.read_csv('average_paths_dse.csv')
average_paths_df['date'] = pd.to_datetime(average_paths_df['date'])

# Initialize the dse_mape DataFrame
columns = ['1_week', '2_week', '3_week', '1_month', '2_month', '6_month', '12_month']
dse_mape = pd.DataFrame(index=dse_df_2023['ticker'].unique(), columns=columns)

# Time marks in business days (approximation)
time_marks = {
    '1_week': 5,
    '2_week': 9,
    '3_week': 15,
    '1_month': 20,
    '2_month': 40,
    '6_month': 120,
    '12_month': 230
}

# Calculate MAPE for each ticker
for ticker in dse_df_2023['ticker'].unique():
    actual_prices = dse_df_2023[dse_df_2023['ticker'] == ticker].set_index('date')['close']
    predicted_prices = average_paths_df.set_index('date')[ticker]

    for period, days in time_marks.items():
        if len(actual_prices) > days:
            actual_price = actual_prices.iloc[days]
            predicted_price = predicted_prices.iloc[days]

            mape = calculate_mape(actual_price, predicted_price)
            dse_mape.at[ticker, period] = mape

# Sort the dse_mape DataFrame by ticker
dse_mape_sorted = dse_mape.sort_index()

# Save the dse_mape DataFrame to a CSV file
dse_mape.to_csv('dse_mape.csv')

# Display the first few rows of the dse_mape DataFrame to verify
print(dse_mape)
# Out:
#               1_week    2_week     3_week    1_month    2_month    6_month  \
# 00DS30      0.180024  0.741582   1.348716   2.839238   3.518062   7.081283
# UPGDCL      0.151379  0.242343   0.363592   0.515228   1.019289   3.328555
# UNIQUEHRL    1.47271   6.99663   9.642564  19.373072   6.682733  15.896646
# TITASGAS    0.316922  0.642949   1.055506   1.341588   2.678294   7.170558
# SQURPHARMA  0.049658  0.123844   0.187845   0.291541   0.589207   1.612899
# SOUTHEASTB  0.330588  0.580954   0.946348   1.205419   2.382083    3.43103
# SEAPEARL    7.366164  8.844382  13.765773  23.045601  10.680321   84.33164
# ROBI        0.324952  0.514069   0.921467   1.280916   2.451009   7.443399
# RENATA       0.15687  0.315144   0.558228   0.743423   1.484492   4.021924
# ORIONPHARM  1.636332  4.162934   3.718109   3.427555   1.880937   2.826399
# OLYMPIC     0.102609  0.474112   0.212039   8.923272  18.591843  27.757176
# MPETROLEUM   0.02405   0.00091   0.013549    0.02864   0.104094   1.020438
# LHBL         0.36546  0.502635   0.779572   1.071028   1.771907  11.069447
# ISLAMIBANK  0.413503  0.181306    0.68687   0.054582   0.786413   2.538149
# IFIC        0.955659  1.704999   2.758871   3.570395   6.918924  16.891359
# IDLC        0.687668  1.180757   1.914166   2.575984   4.884051  13.147389
# POWERGRID   0.313213  0.615335   0.960739   1.326308   2.271263   7.611972
# GP          0.502245  0.859625   1.348361   1.812154    3.32169   9.792092
# GPHISPAT    0.543895  0.862375   1.190069    1.58162   3.089191     9.0039
# BATBC       0.496937  0.811458   1.404692    1.81815   3.508989  10.156271
# BBSCABLES   0.336546  0.572393   0.848177   1.107268   2.210843   5.974102
# BEACONPHAR  9.383772  5.792963   5.231043   3.935789   4.887364   37.07693
# BEXIMCO     0.717555  1.288828   1.873124   2.492252   4.892478  13.195083
# BRACBANK    0.945607  1.565924   2.493018   3.268035   6.195059  10.847428
# BSC         3.148084  6.006825   7.499894   5.952869   3.687831  20.670502
# 00DSEX      0.005692  0.513959   1.320802   2.030416   1.439993    6.30959
# BSRMLTD     0.459702  0.736456   1.084316   1.419343   2.580764   7.491366
# BXPHARMA    0.770481    1.4361   2.700427   3.160889    5.12496  13.988313
# CITYBANK    0.546572  0.919167   1.504471   1.982898   3.942025   9.592248
# DELTALIFE   0.934233  1.725116   2.222409   2.918419   5.852116  26.247319
# FORTUNE     0.645261  1.082028   1.562146   2.184388   4.209596  11.973232
# BSCCL       0.177156  0.222496   0.358792   0.361975   0.826683   2.089086
#
#              12_month
# 00DS30       9.764623
# UPGDCL            NaN
# UNIQUEHRL   11.604082
# TITASGAS          NaN
# SQURPHARMA   2.908805
# SOUTHEASTB        NaN
# SEAPEARL    477.16569
# ROBI         13.51854
# RENATA            NaN
# ORIONPHARM   7.981378
# OLYMPIC     35.257678
# MPETROLEUM    0.74705
# LHBL        14.943185
# ISLAMIBANK        NaN
# IFIC        31.468326
# IDLC              NaN
# POWERGRID         NaN
# GP           17.96084
# GPHISPAT          NaN
# BATBC       18.656085
# BBSCABLES         NaN
# BEACONPHAR        NaN
# BEXIMCO     23.072877
# BRACBANK    24.982108
# BSC         71.112381
# 00DSEX       8.877075
# BSRMLTD           NaN
# BXPHARMA    24.616672
# CITYBANK    18.865693
# DELTALIFE   30.283884
# FORTUNE           NaN
# BSCCL             NaN

# %%
# Sort hose_mape and dse_mape DataFrames by ticker, save them to CSV files, and display the first few rows of hose_mape
hose_mape = hose_mape.sort_index()
hose_mape.to_csv('hose_mape.csv')
dse_mape = dse_mape.sort_index()
dse_mape.to_csv('dse_mape.csv')
# Out:
#        1_week     2_week     3_week    1_month    2_month    6_month  \
# ACB  7.374319  15.006332  18.247182  14.724767  20.116096  20.685555
# BCM  1.911359   3.232342   4.309744   3.455058     1.0229  12.385007
# BID  4.743284  12.505548  12.744901  11.259949  16.927973   8.012674
# BVH  3.311404   4.949126   8.771065   7.010418    8.54407   3.054115
# CTG  4.631757  11.390235  11.480851  10.388973  10.679559  17.232775
#
#       12_month
# ACB   42.58275
# BCM  59.250516
# BID   7.315655
# BVH   1.235722
# CTG  20.516486
#               1_week    2_week    3_week   1_month   2_month    6_month  \
# 00DS30      0.180024  0.741582  1.348716  2.839238  3.518062   7.081283
# 00DSEX      0.005692  0.513959  1.320802  2.030416  1.439993    6.30959
# BATBC       0.496937  0.811458  1.404692   1.81815  3.508989  10.156271
# BBSCABLES   0.336546  0.572393  0.848177  1.107268  2.210843   5.974102
# BEACONPHAR  9.383772  5.792963  5.231043  3.935789  4.887364   37.07693
#
#              12_month
# 00DS30       9.764623
# 00DSEX       8.877075
# BATBC       18.656085
# BBSCABLES         NaN
# BEACONPHAR        NaN

# %%
import pandas as pd

# Load data
dse_mape = pd.read_csv('./mape/dse_mape.csv')
dse_df_2023 = pd.read_csv('./data/dse_df_2023.csv')
dse_average = pd.read_csv('./average_paths_dse.csv')

# Convert date columns to datetime
dse_df_2023['date'] = pd.to_datetime(dse_df_2023['date'])
dse_average['date'] = pd.to_datetime(dse_average['date'])

# Sort dse_df_2023 and dse_average by date and ticker
dse_df_2023 = dse_df_2023.sort_values(by=['ticker', 'date'])
dse_average = dse_average.sort_values(by='date')

# Sample tickers (replace this with your actual unique tickers)
unique_tickers = dse_df_2023['ticker'].unique()

# Create an empty DataFrame 'dse_short_term' with tickers as index
dse_short_term = pd.DataFrame(index=unique_tickers)


# Extract actual, predicted prices and MAPE for each period
periods = {
    '1_week': 5,
    '2_week': 9,
    '3_week': 15,
    '1_month': 20,
}

for period, index in periods.items():
    actual_prices = [get_close_price_at_index(dse_df_2023, ticker, index) for ticker in unique_tickers]
    dse_short_term[f'{period}_actual'] = actual_prices
    
    predicted_prices = dse_average.iloc[index, 1:33].values
    dse_short_term[f'{period}_predict'] = predicted_prices
    
    dse_short_term[f'{period}_mape'] = dse_mape[period].values

# Save as a CSV file to the 'mape' folder
dse_short_term.to_csv('./mape/dse_short_term.csv')

# Display the first few rows of the DataFrame
dse_short_term.head()
# Out:
#             1_week_actual 1_week_predict  1_week_mape  2_week_actual  \
# 00DS30         2191.50951    2187.564266     0.180024     2199.04861
# 00DSEX         6192.30575      6191.9533     0.005692     6215.04937
# BATBC           518.70000     516.122386     0.496937      518.70000
# BBSCABLES        49.90000      49.732063     0.336546       49.90000
# BEACONPHAR      279.60000     305.837027     9.383772      289.80000
#
#            2_week_predict  2_week_mape  3_week_actual 3_week_predict  \
# 00DS30        2182.740862     0.741582     2204.34962    2174.619208
# 00DSEX        6183.106539     0.513959     6255.93088    6173.302416
# BATBC          514.490966     0.811458      518.70000     511.413862
# BBSCABLES       49.614376     0.572393       49.90000       49.47676
# BEACONPHAR     306.588008     5.792963      292.70000     308.011264
#
#             3_week_mape  1_month_actual 1_month_predict  1_month_mape
# 00DS30         1.348716      2231.25795     2167.907217      2.839238
# 00DSEX         1.320802      6288.33426     6160.654944      2.030416
# BATBC          1.404692       518.70000      509.269256      1.818150
# BBSCABLES      0.848177        49.90000       49.347473      1.107268
# BEACONPHAR     5.231043       322.00000       309.32676      3.935789

# %%
import pandas as pd

# Load data
dse_mape = pd.read_csv('./mape/dse_mape.csv')
dse_df_2023 = pd.read_csv('./data/dse_df_2023.csv')
dse_average = pd.read_csv('./average_paths_dse.csv')

# Convert date columns to datetime
dse_df_2023['date'] = pd.to_datetime(dse_df_2023['date'])
dse_average['date'] = pd.to_datetime(dse_average['date'])

# Sort dse_df_2023 and dse_average by date and ticker
dse_df_2023 = dse_df_2023.sort_values(by=['ticker', 'date'])
dse_average = dse_average.sort_values(by='date')

# Sample tickers (replace this with your actual unique tickers)
unique_tickers = dse_df_2023['ticker'].unique()

# Create an empty DataFrame 'dse_long_term' with tickers as index
dse_long_term = pd.DataFrame(index=unique_tickers)

# Extract actual, predicted prices and MAPE for each period
periods = {
    '2_month': 40,
    '6_month': 120,
    '12_month': 230
    }

for period, index in periods.items():
    actual_prices = [get_close_price_at_index(dse_df_2023, ticker, index) for ticker in unique_tickers]
    dse_long_term[f'{period}_actual'] = actual_prices
    
    predicted_prices = dse_average.iloc[index, 1:33].values
    dse_long_term[f'{period}_predict'] = predicted_prices
    
    dse_long_term[f'{period}_mape'] = dse_mape[period].values

# Save as a CSV file to the 'mape' folder
dse_long_term.to_csv('./mape/dse_long_term.csv')

# Display the first few rows of the DataFrame
dse_long_term.head()
# Out:
#             2_month_actual 2_month_predict  2_month_mape  6_month_actual  \
# 00DS30          2218.77336     2140.715526      3.518062      2192.87668
# 00DSEX          6199.20375     6109.935653      1.439993      6336.14790
# BATBC            518.70000      500.498875      3.508989       518.70000
# BBSCABLES         49.90000       48.796789      2.210843        49.90000
# BEACONPHAR       300.30000      314.976754      4.887364       245.00000
#
#            6_month_predict  6_month_mape  12_month_actual 12_month_predict  \
# 00DS30         2037.592866      7.081283       2107.12353      1901.370854
# 00DSEX         5936.362927      6.309590       6266.85182      5710.538665
# BATBC           466.019425     10.156271        518.70000       421.930889
# BBSCABLES        46.918923      5.974102              NaN        44.347466
# BEACONPHAR      335.838478     37.076930              NaN       354.587564
#
#             12_month_mape
# 00DS30           9.764623
# 00DSEX           8.877075
# BATBC           18.656085
# BBSCABLES             NaN
# BEACONPHAR            NaN
