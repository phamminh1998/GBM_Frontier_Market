# %%
import importlib.util
import subprocess
import sys

def install_and_import(module_name):
    if importlib.util.find_spec(module_name) is None:
        print(f"{module_name} not found. Installing...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", module_name])
    else:
        print(f"{module_name} is already installed.")

# Use the function for the libraries
install_and_import('pandas')
install_and_import('numpy')
install_and_import('matplotlib')
install_and_import('statsmodels')
# Out:
# pandas is already installed.
# numpy is already installed.
# matplotlib is already installed.
# statsmodels is already installed.

# %% [markdown]
# # 1. ARIMA fitting and prediction for HOSE

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# Read the data
hose_df_2022 = pd.read_csv('./data/hose_df_2022.csv')
hose_df_2023 = pd.read_csv('./data/hose_df_2023.csv')

# Convert 'date' column to datetime
hose_df_2022['date'] = pd.to_datetime(hose_df_2022['date'])
hose_df_2023['date'] = pd.to_datetime(hose_df_2023['date'])

# Sort the dataframes by 'ticker' and 'date'
hose_df_2022 = hose_df_2022.sort_values(by=['ticker', 'date'])
hose_df_2023 = hose_df_2023.sort_values(by=['ticker', 'date'])

# Step 1: Create an empty DataFrame with dates from hose_df_2023
dates_2023 = sorted(hose_df_2023['date'].unique())
hose_arima_pred = pd.DataFrame({'date': dates_2023})

# Add columns for each ticker
for ticker in hose_df_2022['ticker'].unique():
    hose_arima_pred[ticker] = None

# Set the 'date' column as the index
hose_arima_pred.set_index('date', inplace=True)

# Step 2: For loop for each ticker
for ticker in hose_df_2022['ticker'].unique():
    # Extract 'date' and 'close' price series for the current ticker from hose_df_2022
    ticker_data = hose_df_2022.loc[hose_df_2022['ticker'] == ticker, ['date', 'close']]
    
    # Set 'date' as the index
    ticker_data.set_index('date', inplace=True)
    
    # Fit an ARIMA(1,1,1) model
    model = ARIMA(ticker_data, order=(1, 1, 0))
    model_fit = model.fit()
    
    # Predict 249 days forward
    forecast = model_fit.forecast(steps=249)
    
    # Ensure the forecast index aligns with the prediction dates
    forecast_dates = hose_arima_pred.index[:249]  # Get the first 249 dates from hose_arima_pred
    
    # Fill the predicted values into the corresponding column of the DataFrame
    hose_arima_pred.loc[forecast_dates, ticker] = forecast.values

# Display the predictions DataFrame
print(hose_arima_pred)
hose_arima_pred.to_csv('hose_arima_pred.csv', index=True)
# Out:
# c:\Users\MINH\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\MINH\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\MINH\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %% [markdown]
# # 2. ARIMA fitting and prediction for DSE

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# Read the data
dse_df_2022 = pd.read_csv('./data/dse_df_2022.csv')
dse_df_2023 = pd.read_csv('./data/dse_df_2023.csv')

# Convert 'date' column to datetime
dse_df_2022['date'] = pd.to_datetime(dse_df_2022['date'])
dse_df_2023['date'] = pd.to_datetime(dse_df_2023['date'])

# Sort the dataframes by 'ticker' and 'date'
dse_df_2022 = dse_df_2022.sort_values(by=['ticker', 'date'])
dse_df_2023 = dse_df_2023.sort_values(by=['ticker', 'date'])

# Step 1: Create an empty DataFrame with dates from dse_df_2023
dates_2023 = sorted(dse_df_2023['date'].unique())
dse_arima_pred = pd.DataFrame({'date': dates_2023})

# Add columns for each ticker
for ticker in dse_df_2022['ticker'].unique():
    dse_arima_pred[ticker] = None

# Set the 'date' column as the index
dse_arima_pred.set_index('date', inplace=True)

# Step 2: For loop for each ticker
for ticker in dse_df_2022['ticker'].unique():
    # Extract 'date' and 'close' price series for the current ticker from dse_df_2022
    ticker_data = dse_df_2022.loc[dse_df_2022['ticker'] == ticker, ['date', 'close']]
    
    # Set 'date' as the index
    ticker_data.set_index('date', inplace=True)
    
    # Fit an ARIMA(1, 1, 1) model
    model = ARIMA(ticker_data, order=(1, 1, 0))
    model_fit = model.fit()
    
    # Predict 249 days forward
    forecast = model_fit.forecast(steps=240)
    
    # Ensure the forecast index aligns with the prediction dates
    forecast_dates = dse_arima_pred.index[:240]  # Get the first 249 dates from dse_arima_pred
    
    # Fill the predicted values into the corresponding column of the DataFrame
    dse_arima_pred.loc[forecast_dates, ticker] = forecast.values

# Display the predictions DataFrame
print(dse_arima_pred)

# Save the predictions DataFrame to a CSV file in the root directory
dse_arima_pred.to_csv('dse_arima_pred.csv', index=True)
# Out:
# c:\Users\MINH\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\MINH\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\MINH\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...
